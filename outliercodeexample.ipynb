# %%
import pandas as pd
import Helper as hp

# %%
# Example usage
df = pd.read_csv("C:/Users/Ryan Satterfield/Documents/GitHub/FinalProject/Resources/Data/BrooklynHomesPostgres.csv")
#df = df[df['neighborhood'] == 'BOREM HILL']
df = hp.remove_outliers(df, "sale_price", threshold=2)
df
# Out:
# C:\Users\Ryan Satterfield\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3398: DtypeWarning: Columns (8,34,36,69) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            id  borough      neighborhood building_class_category  block  lot  \
# 2768     9968        3        PARK SLOPE   03 THREE FAMILY HOMES    970   36
# 2769     9969        3  BROOKLYN HEIGHTS     02 TWO FAMILY HOMES    274    3
# 2770     9972        3      CLINTON HILL     02 TWO FAMILY HOMES   1904    5
# 2771     9973        3      BOROUGH PARK     01 ONE FAMILY HOMES   5434   59
# 2772     9974        3   CARROLL GARDENS   03 THREE FAMILY HOMES    408   36
# ...       ...      ...               ...                     ...    ...  ...
# 78678  166392        3     EAST NEW YORK     01 ONE FAMILY HOMES   4009   31
# 78679  166393        3     EAST NEW YORK     02 TWO FAMILY HOMES   3979    1
# ...

# %%
df
# Out:
#            id  borough      neighborhood building_class_category  block  lot  \
# 2768     9968        3        PARK SLOPE   03 THREE FAMILY HOMES    970   36
# 2769     9969        3  BROOKLYN HEIGHTS     02 TWO FAMILY HOMES    274    3
# 2770     9972        3      CLINTON HILL     02 TWO FAMILY HOMES   1904    5
# 2771     9973        3      BOROUGH PARK     01 ONE FAMILY HOMES   5434   59
# 2772     9974        3   CARROLL GARDENS   03 THREE FAMILY HOMES    408   36
# ...       ...      ...               ...                     ...    ...  ...
# 78678  166392        3     EAST NEW YORK     01 ONE FAMILY HOMES   4009   31
# 78679  166393        3     EAST NEW YORK     02 TWO FAMILY HOMES   3979    1
# 78680  166394        3     EAST NEW YORK   03 THREE FAMILY HOMES   3688   30
# 78681  166395        3     FLATBUSH-EAST     02 TWO FAMILY HOMES   4953   50
# 78682  166403        3       SUNSET PARK   03 THREE FAMILY HOMES    708   51
#
# ...
