# %%
import pandas as pd
import numpy as np
import os

# %%
brooklyndf = pd.read_csv("\Resources\Data\brooklyn_sales.csv")
brooklyndf
# jclark: Made recommended changes to corrected CSV from Ryan.
# Out:
# C:\Users\Homer\AppData\Local\Temp\ipykernel_5872\212610442.py:1: DtypeWarning: Columns (40,41,43,45,46,47,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   brooklyndf = pd.read_csv("brooklyn_sales_map.csv")
#         Unnamed: 0  borough           neighborhood  \
# 0                1        3     DOWNTOWN-METROTECH
# 1                2        3  DOWNTOWN-FULTON FERRY
# 2                3        3       BROOKLYN HEIGHTS
# 3                4        3             MILL BASIN
# 4                5        3       BROOKLYN HEIGHTS
# ...            ...      ...                    ...
# 390878      390879        3        WYCKOFF HEIGHTS
# 390879      390880        3        WYCKOFF HEIGHTS
# 390880      390881        3        WYCKOFF HEIGHTS
# 390881      390882        3                   3004
# 390882      390883        3                   3004
#
#            building_class_category tax_class  block   lot  easement  \
# ...

# %%
dfmill = brooklyndf.loc[brooklyndf["neighborhood"]== "MILL BASIN"]
dfmill
# Out:
#         Unnamed: 0  borough neighborhood              building_class_category  \
# 3                4        3   MILL BASIN                  22  STORE BUILDINGS
# 499            500        3   MILL BASIN    08  RENTALS - ELEVATOR APARTMENTS
# 2722          2723        3   MILL BASIN                  01 ONE FAMILY HOMES
# 2723          2724        3   MILL BASIN                        27  FACTORIES
# 5543          5544        3   MILL BASIN  36  OUTDOOR RECREATIONAL FACILITIES
# ...            ...      ...          ...                                  ...
# 383214      383215        3   MILL BASIN                  02 TWO FAMILY HOMES
# 383215      383216        3   MILL BASIN                  02 TWO FAMILY HOMES
# 383216      383217        3   MILL BASIN                03 THREE FAMILY HOMES
# 383217      383218        3   MILL BASIN                03 THREE FAMILY HOMES
# 383218      383219        3   MILL BASIN  36  OUTDOOR RECREATIONAL FACILITIES
#
# ...

# %%
list(dfmill.columns)
# Out:
# ['Unnamed: 0',
#  'borough',
#  'neighborhood',
#  'building_class_category',
#  'tax_class',
#  'block',
#  'lot',
#  'easement',
#  'building_class',
#  'address',
#  'apartment_number',
#  'zip_code',
#  'residential_units',
#  'commercial_units',
#  'total_units',
#  'land_sqft',
#  'gross_sqft',
#  'year_built',
#  'tax_class_at_sale',
#  'building_class_at_sale',
#  'sale_price',
#  'sale_date',
#  'year_of_sale',
#  'Borough',
#  'CD',
#  'CT2010',
#  'CB2010',
#  'SchoolDist',
#  'Council',
#  'ZipCode',
#  'FireComp',
#  'PolicePrct',
#  'HealthCent',
#  'HealthArea',
#  'SanitBoro',
#  'SanitDistr',
#  'SanitSub',
#  'Address',
#  'ZoneDist1',
#  'ZoneDist2',
#  'ZoneDist3',
#  'ZoneDist4',
#  'Overlay1',
#  'Overlay2',
#  'SPDist1',
#  'SPDist2',
#  'SPDist3',
#  'LtdHeight',
#  'SplitZone',
#  'BldgClass',
#  'LandUse',
#  'Easements',
#  'OwnerType',
#  'OwnerName',
#  'LotArea',
#  'BldgArea',
#  'ComArea',
#  'ResArea',
#  'OfficeArea',
#  'RetailArea',
# ...

# %%
dfmill = dfmill[['borough', 'neighborhood', 'building_class_category', 'block', 'lot', 'address', 'SHAPE_Leng', 'SHAPE_Area' ]]

# %%
dfmill
# Out:
#         borough neighborhood              building_class_category  block  \
# 3             3   MILL BASIN                  22  STORE BUILDINGS   8470
# 499           3   MILL BASIN    08  RENTALS - ELEVATOR APARTMENTS   8470
# 2722          3   MILL BASIN                  01 ONE FAMILY HOMES   8470
# 2723          3   MILL BASIN                        27  FACTORIES   8470
# 5543          3   MILL BASIN  36  OUTDOOR RECREATIONAL FACILITIES   8602
# ...         ...          ...                                  ...    ...
# 383214        3   MILL BASIN                  02 TWO FAMILY HOMES   8652
# 383215        3   MILL BASIN                  02 TWO FAMILY HOMES   8654
# 383216        3   MILL BASIN                03 THREE FAMILY HOMES   8466
# 383217        3   MILL BASIN                03 THREE FAMILY HOMES   8638
# 383218        3   MILL BASIN  36  OUTDOOR RECREATIONAL FACILITIES   8616
#
#          lot                  address   SHAPE_Leng     SHAPE_Area
# ...

# %%
dfmill = dfmill.fillna('')

# %%
dfmill
# Out:
#         borough neighborhood              building_class_category  block  \
# 3             3   MILL BASIN                  22  STORE BUILDINGS   8470
# 499           3   MILL BASIN    08  RENTALS - ELEVATOR APARTMENTS   8470
# 2722          3   MILL BASIN                  01 ONE FAMILY HOMES   8470
# 2723          3   MILL BASIN                        27  FACTORIES   8470
# 5543          3   MILL BASIN  36  OUTDOOR RECREATIONAL FACILITIES   8602
# ...         ...          ...                                  ...    ...
# 383214        3   MILL BASIN                  02 TWO FAMILY HOMES   8652
# 383215        3   MILL BASIN                  02 TWO FAMILY HOMES   8654
# 383216        3   MILL BASIN                03 THREE FAMILY HOMES   8466
# 383217        3   MILL BASIN                03 THREE FAMILY HOMES   8638
# 383218        3   MILL BASIN  36  OUTDOOR RECREATIONAL FACILITIES   8616
#
#          lot                  address   SHAPE_Leng     SHAPE_Area
# ...
